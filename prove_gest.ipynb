# %%
class Welcome:

    """
    La classe contiene una welcome screen e accoglie l'anagrafica utente mostrandola all'avvio

    """
    def __init__(self, welcome_text, company_name, address, contacts, vatnumber):
        self.welcome_text=welcome_text
        self.company_name=company_name
        self.address=address
        self.contact=contacts
        self.vatnumber=vatnumber

    def welcomescreen(self):
        self.welcome_text=print(f"Gentile utente, benvenuto alla versione {Version.__version__} del software Simple_Store_Manager")
        return self.welcome_text

    def userdata(self):

        """
        La funzione chiede all'utente i suoi dati e li salva nei parametri init

        """

# %%
storage=open("warehouse.csv", "a+")
storage_writer=csv.writer(storage)
storage_writer.writerow(["PRODOTTO", "QUANTITA", "PREZZO DI ACQUISTO", "PREZZO DI VENDITA"])

# %%
 def filemaker(self):
        storage=open("warehouse.csv", "a+")
        return

# %%
    def writeheader(self):

        """

        In seguito alla verifica e creazione del file warehouse.csv, la funzione writeheader scrive l'header del file csv con le colonne
        che serviranno per salvare i dati inseriti dal cliente.  Se l'header esiste già allora la funzione non esegue nulla.

        """
        
        fields=["PRODOTTO", "QUANTITA'", "PREZZO DI ACQUISTO", "PREZZO DI VENDITA"]
        with open("warehouse.csv", "r") as csvfile:
            try:
                reader=csv.reader(csvfile)
                row1=next(reader)
            except:
                with open("warehouse.csv", "a+", encoding="UTF-8", newline="") as csvfile:
                    writer=csv.DictWriter(csvfile, fieldnames=fields)
                    writer.writeheader()
            return
